# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Shabbir\\Desktop\\YT_Prac\\Text-Summarization-Project\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Shabbir\\Desktop\\YT_Prac\\Text-Summarization-Project'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
import TextSummarizer
from TextSummarizer.constants import *
from TextSummarizer.utils.common import read_yaml, create_directories
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import TextSummarizer
#       2 from TextSummarizer.constants import *
#       3 from TextSummarizer.utils.common import read_yaml, create_directories
#
# ModuleNotFoundError: No module named 'TextSummarizer'

# %%
class configurationManager:
    def __init__(
        self,
        config_filepath=None,
        params_filepath=None,
    ):
        if config_filepath is None:
            config_filepath = CONFIG_FILE_PATH
        if params_filepath is None:
            params_filepath = PARAMS_FILE_PATH
            
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir = config.root_dir,
            source_URL = config.source_URL,
            local_data_file = config.local_data_file,
            unzip_dir = config.unzip_dir,
        )

        return data_ingestion_config

# %%
import os
import urllib.request as request
import zipfile
from TextSummarizer.logging import logger
from TextSummarizer.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config
        
    def download_file(self):
        if not os.path.exists(self.config.local_data_file):
            filename, headers = request.urlretrieve(
                url = self.config.source_URL,
                filename = self.config.local_data_file
            )
            logger.info(
                f"{filename} downloaded! with following info: \n{headers}"
            )
        else:
            logger.info(
                f"File already exists of size: {get_size(Path(self.config.local_data_file))}"
            )

    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file to the date directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir

        os.makedirs(unzip_path, exist_ok=True)

        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %% [markdown]
# # Creating the Pipeline

# %%
try:
    config = configurationManager()
    data_ingestion_config = config.get_data_ingestion_config()

    data_ingestion = DataIngestion(config=data_ingestion_config)

    data_ingestion.download_file()
    data_ingestion.extract_zip_file()

except Exception as e:
    raise e
# Out:
# [2025-11-22 18:08:20,013: INFO: common]: YAML file: config\config.yaml loaded successfully
# [2025-11-22 18:08:20,015: INFO: common]: YAML file: params.yaml loaded successfully
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       8     data_ingestion.extract_zip_file()
#      10 except Exception as e:
# ---> 11     raise e
#
# Cell In[9], line 2
#       1 try:
# ----> 2     config = configurationManager()
#       3     data_ingestion_config = config.get_data_ingestion_config()
#       5     data_ingestion = DataIngestion(config=data_ingestion_config)
#
# Cell In[6], line 15, in configurationManager.__init__(self, config_filepath, params_filepath)
#      12 self.config = read_yaml(config_filepath)
#      13 self.params = read_yaml(params_filepath)
# ---> 15 create_directories([self.config.artifacts_root])
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ensure\main.py:868, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     865 else:
#     866     continue
# --> 868 if not isinstance(value, templ):
#     869     msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
#     870     raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#
# File f:\conda_envs\textSum\Lib\typing.py:1375, in _BaseGenericAlias.__instancecheck__(self, obj)
#    1374 def __instancecheck__(self, obj):
# -> 1375     return self.__subclasscheck__(type(obj))
#
# File f:\conda_envs\textSum\Lib\typing.py:1378, in _BaseGenericAlias.__subclasscheck__(self, cls)
#    1377 def __subclasscheck__(self, cls):
# -> 1378     raise TypeError("Subscripted generics cannot be used with"
#    1379                     " class and instance checks")
#
# TypeError: Subscripted generics cannot be used with class and instance checks
